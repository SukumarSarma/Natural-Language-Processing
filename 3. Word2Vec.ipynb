# %%
import nltk
from nltk.stem import WordNetLemmatizer
import re
from nltk.corpus import stopwords
from gensim.models import Word2Vec

# %%
paragraph="""Darjeeling is a city and a municipality in the Indian state of West Bengal. It is located in the Lesser Himalayas at an elevation of 2,000 metres (6,560 ft).
           It is noted for its tea industry, its views of the world's third-highest mountain Kangchenjunga, and the Darjeeling Himalayan Railway, a UNESCO World Heritage Site. 
           Darjeeling is the headquarters of the Darjeeling district which has a partially autonomous status called Gorkhaland Territorial Administration within the state of 
           West Bengal. It is also a popular tourist destination in India.
           The recorded history of the town starts from the early 19th century when the colonial administration under the British Raj set up a sanatorium and a military depot 
           in the region. Subsequently, extensive tea plantations were established in the region and tea growers developed hybrids of black tea and created new fermentation 
           techniques. The resultant distinctive Darjeeling tea is internationally recognised and ranks among the most popular black teas in the world.[6] The Darjeeling 
           Himalayan Railway connects the town with the plains and has some of the few steam locomotives still in service in India.
           Darjeeling has several British-style private schools, which attract pupils from all over India and a few neighbouring countries. The varied culture of the town 
           reflects its diverse demographic milieu comprising Lepcha, Khampa, Gorkha, Kirati, Newar, Sherpa, Bhutia, Bengali[7] and other mainland Indian ethno-linguistic groups. 
           Darjeeling, alongside its neighbouring town of Kalimpong, was the centre of the Gorkhaland social movement in the 1980s and summer 2017."""

# %%
text=re.sub('[^a-zA-Z]',' ',paragraph)
text=text.lower()
text
# Out:
# 'darjeeling is a city and a municipality in the indian state of west bengal  it is located in the lesser himalayas at an elevation of       metres        ft              it is noted for its tea industry  its views of the world s third highest mountain kangchenjunga  and the darjeeling himalayan railway  a unesco world heritage site              darjeeling is the headquarters of the darjeeling district which has a partially autonomous status called gorkhaland territorial administration within the state of             west bengal  it is also a popular tourist destination in india             the recorded history of the town starts from the early   th century when the colonial administration under the british raj set up a sanatorium and a military depot             in the region  subsequently  extensive tea plantations were established in the region and tea growers developed hybrids of black tea and created new fermentation             techniques  the resultant distinctive darjeeling tea is internationally recognised and ranks among the most popular black teas in the world     the darjeeling             himalayan railway connects the town with the plains and has some of the few steam locomotives still in service in india             darjeeling has several british style private schools  which attract pupils from all over india and a few neighbouring countries  the varied culture of the town             reflects its diverse demographic milieu comprising lepcha  khampa  gorkha  kirati  newar  sherpa  bhutia  bengali    and other mainland indian ethno linguistic groups              darjeeling  alongside its neighbouring town of kalimpong  was the centre of the gorkhaland social movement in the     s and summer      '

# %%
sentences=nltk.sent_tokenize(text)
sentences
# Out:
# ['darjeeling is a city and a municipality in the indian state of west bengal  it is located in the lesser himalayas at an elevation of       metres        ft              it is noted for its tea industry  its views of the world s third highest mountain kangchenjunga  and the darjeeling himalayan railway  a unesco world heritage site              darjeeling is the headquarters of the darjeeling district which has a partially autonomous status called gorkhaland territorial administration within the state of             west bengal  it is also a popular tourist destination in india             the recorded history of the town starts from the early   th century when the colonial administration under the british raj set up a sanatorium and a military depot             in the region  subsequently  extensive tea plantations were established in the region and tea growers developed hybrids of black tea and created new fermentation             techniques  the resultant distinctive darjeeling tea is internationally recognised and ranks among the most popular black teas in the world     the darjeeling             himalayan railway connects the town with the plains and has some of the few steam locomotives still in service in india             darjeeling has several british style private schools  which attract pupils from all over india and a few neighbouring countries  the varied culture of the town             reflects its diverse demographic milieu comprising lepcha  khampa  gorkha  kirati  newar  sherpa  bhutia  bengali    and other mainland indian ethno linguistic groups              darjeeling  alongside its neighbouring town of kalimpong  was the centre of the gorkhaland social movement in the     s and summer']

# %%
sentences=[nltk.word_tokenize(sentence) for sentence in sentences]
sentences
# Out:
# [['darjeeling',
#   'is',
#   'a',
#   'city',
#   'and',
#   'a',
#   'municipality',
#   'in',
#   'the',
#   'indian',
#   'state',
#   'of',
#   'west',
#   'bengal',
#   'it',
#   'is',
#   'located',
#   'in',
#   'the',
#   'lesser',
#   'himalayas',
#   'at',
#   'an',
#   'elevation',
#   'of',
#   'metres',
#   'ft',
#   'it',
#   'is',
#   'noted',
#   'for',
#   'its',
#   'tea',
#   'industry',
#   'its',
#   'views',
#   'of',
#   'the',
#   'world',
#   's',
#   'third',
#   'highest',
#   'mountain',
#   'kangchenjunga',
#   'and',
#   'the',
#   'darjeeling',
#   'himalayan',
#   'railway',
#   'a',
#   'unesco',
#   'world',
#   'heritage',
#   'site',
#   'darjeeling',
#   'is',
#   'the',
#   'headquarters',
#   'of',
#   'the',
#   'darjeeling',
#   'district',
#   'which',
#   'has',
#   'a',
#   'partially',
#   'autonomous',
#   'status',
#   'called',
#   'gorkhaland',
#   'territorial',
#   'administration',
#   'within',
#   'the',
#   'state',
#   'of',
#   'west',
#   'bengal',
#   'it',
#   'is',
#   'also',
#   'a',
#   'popular',
#   'tourist',
#   'destination',
#   'in',
#   'india',
#   'the',
#   'recorded',
#   'history',
#   'of',
#   'the',
#   'town',
#   'starts',
#   'from',
#   'the',
#   'early',
#   'th',
#   'century',
#   'when',
#   'the',
#   'colonial',
#   'administration',
#   'under',
#   'the',
#   'british',
#   'raj',
#   'set',
#   'up',
#   'a',
#   'sanatorium',
#   'and',
#   'a',
#   'military',
#   'depot',
#   'in',
#   'the',
#   'region',
#   'subsequently',
#   'extensive',
#   'tea',
#   'plantations',
#   'were',
#   'established',
#   'in',
#   'the',
#   'region',
#   'and',
#   'tea',
#   'growers',
#   'developed',
#   'hybrids',
#   'of',
#   'black',
#   'tea',
#   'and',
#   'created',
#   'new',
#   'fermentation',
#   'techniques',
#   'the',
#   'resultant',
#   'distinctive',
#   'darjeeling',
#   'tea',
#   'is',
#   'internationally',
#   'recognised',
#   'and',
#   'ranks',
#   'among',
#   'the',
#   'most',
#   'popular',
#   'black',
#   'teas',
#   'in',
#   'the',
#   'world',
#   'the',
#   'darjeeling',
#   'himalayan',
#   'railway',
#   'connects',
#   'the',
#   'town',
#   'with',
#   'the',
#   'plains',
#   'and',
#   'has',
#   'some',
#   'of',
#   'the',
#   'few',
#   'steam',
#   'locomotives',
#   'still',
#   'in',
#   'service',
#   'in',
#   'india',
#   'darjeeling',
#   'has',
#   'several',
#   'british',
#   'style',
#   'private',
#   'schools',
#   'which',
#   'attract',
#   'pupils',
#   'from',
#   'all',
#   'over',
#   'india',
#   'and',
#   'a',
#   'few',
#   'neighbouring',
#   'countries',
#   'the',
#   'varied',
#   'culture',
#   'of',
#   'the',
#   'town',
#   'reflects',
#   'its',
#   'diverse',
#   'demographic',
#   'milieu',
#   'comprising',
#   'lepcha',
#   'khampa',
#   'gorkha',
#   'kirati',
#   'newar',
#   'sherpa',
#   'bhutia',
#   'bengali',
#   'and',
#   'other',
#   'mainland',
#   'indian',
#   'ethno',
#   'linguistic',
#   'groups',
#   'darjeeling',
#   'alongside',
#   'its',
#   'neighbouring',
#   'town',
#   'of',
#   'kalimpong',
#   'was',
#   'the',
#   'centre',
#   'of',
#   'the',
#   'gorkhaland',
#   'social',
#   'movement',
#   'in',
#   'the',
#   's',
#   'and',
#   'summer']]

# %%
for i in range(len(sentences)):
    sentences[i]=[word for word in sentences[i] if word not in stopwords.words('english')]
sentences
# Out:
# [['darjeeling',
#   'city',
#   'municipality',
#   'indian',
#   'state',
#   'west',
#   'bengal',
#   'located',
#   'lesser',
#   'himalayas',
#   'elevation',
#   'metres',
#   'ft',
#   'noted',
#   'tea',
#   'industry',
#   'views',
#   'world',
#   'third',
#   'highest',
#   'mountain',
#   'kangchenjunga',
#   'darjeeling',
#   'himalayan',
#   'railway',
#   'unesco',
#   'world',
#   'heritage',
#   'site',
#   'darjeeling',
#   'headquarters',
#   'darjeeling',
#   'district',
#   'partially',
#   'autonomous',
#   'status',
#   'called',
#   'gorkhaland',
#   'territorial',
#   'administration',
#   'within',
#   'state',
#   'west',
#   'bengal',
#   'also',
#   'popular',
#   'tourist',
#   'destination',
#   'india',
#   'recorded',
#   'history',
#   'town',
#   'starts',
#   'early',
#   'th',
#   'century',
#   'colonial',
#   'administration',
#   'british',
#   'raj',
#   'set',
#   'sanatorium',
#   'military',
#   'depot',
#   'region',
#   'subsequently',
#   'extensive',
#   'tea',
#   'plantations',
#   'established',
#   'region',
#   'tea',
#   'growers',
#   'developed',
#   'hybrids',
#   'black',
#   'tea',
#   'created',
#   'new',
#   'fermentation',
#   'techniques',
#   'resultant',
#   'distinctive',
#   'darjeeling',
#   'tea',
#   'internationally',
#   'recognised',
#   'ranks',
#   'among',
#   'popular',
#   'black',
#   'teas',
#   'world',
#   'darjeeling',
#   'himalayan',
#   'railway',
#   'connects',
#   'town',
#   'plains',
#   'steam',
#   'locomotives',
#   'still',
#   'service',
#   'india',
#   'darjeeling',
#   'several',
#   'british',
#   'style',
#   'private',
#   'schools',
#   'attract',
#   'pupils',
#   'india',
#   'neighbouring',
#   'countries',
#   'varied',
#   'culture',
#   'town',
#   'reflects',
#   'diverse',
#   'demographic',
#   'milieu',
#   'comprising',
#   'lepcha',
#   'khampa',
#   'gorkha',
#   'kirati',
#   'newar',
#   'sherpa',
#   'bhutia',
#   'bengali',
#   'mainland',
#   'indian',
#   'ethno',
#   'linguistic',
#   'groups',
#   'darjeeling',
#   'alongside',
#   'neighbouring',
#   'town',
#   'kalimpong',
#   'centre',
#   'gorkhaland',
#   'social',
#   'movement',
#   'summer']]

# %%
model=Word2Vec(sentences,min_count=1)
words=model.wv.vocab
words
# Out:
# C:\Users\Sukumar\AppData\Local\Programs\Python\Python38\lib\site-packages\gensim\models\base_any2vec.py:742: UserWarning: C extension not loaded, training will be slow. Install a C compiler and reinstall gensim for fast training.
#   warnings.warn(
# {'darjeeling': <gensim.models.keyedvectors.Vocab at 0x1a732e63ca0>,
#  'city': <gensim.models.keyedvectors.Vocab at 0x1a732e63a60>,
#  'municipality': <gensim.models.keyedvectors.Vocab at 0x1a732e63c40>,
#  'indian': <gensim.models.keyedvectors.Vocab at 0x1a732e63af0>,
#  'state': <gensim.models.keyedvectors.Vocab at 0x1a732d5edf0>,
#  'west': <gensim.models.keyedvectors.Vocab at 0x1a732d5ea00>,
#  'bengal': <gensim.models.keyedvectors.Vocab at 0x1a732d5e370>,
#  'located': <gensim.models.keyedvectors.Vocab at 0x1a732d5e2e0>,
#  'lesser': <gensim.models.keyedvectors.Vocab at 0x1a732d5e6d0>,
#  'himalayas': <gensim.models.keyedvectors.Vocab at 0x1a732d5ee20>,
#  'elevation': <gensim.models.keyedvectors.Vocab at 0x1a732d5e670>,
#  'metres': <gensim.models.keyedvectors.Vocab at 0x1a732d5ed00>,
#  'ft': <gensim.models.keyedvectors.Vocab at 0x1a732d5ea30>,
#  'noted': <gensim.models.keyedvectors.Vocab at 0x1a732d5e430>,
#  'tea': <gensim.models.keyedvectors.Vocab at 0x1a732d5e280>,
#  'industry': <gensim.models.keyedvectors.Vocab at 0x1a732d5e1f0>,
#  'views': <gensim.models.keyedvectors.Vocab at 0x1a732e37880>,
#  'world': <gensim.models.keyedvectors.Vocab at 0x1a732e37070>,
#  'third': <gensim.models.keyedvectors.Vocab at 0x1a732e370d0>,
#  'highest': <gensim.models.keyedvectors.Vocab at 0x1a732e37130>,
#  'mountain': <gensim.models.keyedvectors.Vocab at 0x1a732e37190>,
#  'kangchenjunga': <gensim.models.keyedvectors.Vocab at 0x1a732e371f0>,
#  'himalayan': <gensim.models.keyedvectors.Vocab at 0x1a732e37250>,
#  'railway': <gensim.models.keyedvectors.Vocab at 0x1a732e372b0>,
#  'unesco': <gensim.models.keyedvectors.Vocab at 0x1a732e37340>,
#  'heritage': <gensim.models.keyedvectors.Vocab at 0x1a732e373d0>,
#  'site': <gensim.models.keyedvectors.Vocab at 0x1a732e37430>,
#  'headquarters': <gensim.models.keyedvectors.Vocab at 0x1a732e37490>,
#  'district': <gensim.models.keyedvectors.Vocab at 0x1a732e374f0>,
#  'partially': <gensim.models.keyedvectors.Vocab at 0x1a732e37550>,
#  'autonomous': <gensim.models.keyedvectors.Vocab at 0x1a732e375b0>,
#  'status': <gensim.models.keyedvectors.Vocab at 0x1a732e372e0>,
#  'called': <gensim.models.keyedvectors.Vocab at 0x1a732e37640>,
#  'gorkhaland': <gensim.models.keyedvectors.Vocab at 0x1a732e37670>,
#  'territorial': <gensim.models.keyedvectors.Vocab at 0x1a732e376d0>,
#  'administration': <gensim.models.keyedvectors.Vocab at 0x1a732e37730>,
#  'within': <gensim.models.keyedvectors.Vocab at 0x1a732e37790>,
#  'also': <gensim.models.keyedvectors.Vocab at 0x1a732e377f0>,
#  'popular': <gensim.models.keyedvectors.Vocab at 0x1a732e37850>,
#  'tourist': <gensim.models.keyedvectors.Vocab at 0x1a732e378e0>,
#  'destination': <gensim.models.keyedvectors.Vocab at 0x1a732e37970>,
#  'india': <gensim.models.keyedvectors.Vocab at 0x1a732e379d0>,
#  'recorded': <gensim.models.keyedvectors.Vocab at 0x1a732e37a30>,
#  'history': <gensim.models.keyedvectors.Vocab at 0x1a732e37a90>,
#  'town': <gensim.models.keyedvectors.Vocab at 0x1a732e37af0>,
#  'starts': <gensim.models.keyedvectors.Vocab at 0x1a732e37b50>,
#  'early': <gensim.models.keyedvectors.Vocab at 0x1a732e37bb0>,
#  'th': <gensim.models.keyedvectors.Vocab at 0x1a732e37c10>,
#  'century': <gensim.models.keyedvectors.Vocab at 0x1a732e37c70>,
#  'colonial': <gensim.models.keyedvectors.Vocab at 0x1a732e37cd0>,
#  'british': <gensim.models.keyedvectors.Vocab at 0x1a732e37d30>,
#  'raj': <gensim.models.keyedvectors.Vocab at 0x1a732e37d90>,
#  'set': <gensim.models.keyedvectors.Vocab at 0x1a732e37df0>,
#  'sanatorium': <gensim.models.keyedvectors.Vocab at 0x1a732e37e50>,
#  'military': <gensim.models.keyedvectors.Vocab at 0x1a732e37eb0>,
#  'depot': <gensim.models.keyedvectors.Vocab at 0x1a732e37f10>,
#  'region': <gensim.models.keyedvectors.Vocab at 0x1a732e37f70>,
#  'subsequently': <gensim.models.keyedvectors.Vocab at 0x1a732e37fd0>,
#  'extensive': <gensim.models.keyedvectors.Vocab at 0x1a732e62070>,
#  'plantations': <gensim.models.keyedvectors.Vocab at 0x1a732e620d0>,
#  'established': <gensim.models.keyedvectors.Vocab at 0x1a732e62130>,
#  'growers': <gensim.models.keyedvectors.Vocab at 0x1a732e62190>,
#  'developed': <gensim.models.keyedvectors.Vocab at 0x1a732e621f0>,
#  'hybrids': <gensim.models.keyedvectors.Vocab at 0x1a732e62250>,
#  'black': <gensim.models.keyedvectors.Vocab at 0x1a732e622b0>,
#  'created': <gensim.models.keyedvectors.Vocab at 0x1a732e62310>,
#  'new': <gensim.models.keyedvectors.Vocab at 0x1a732e62370>,
#  'fermentation': <gensim.models.keyedvectors.Vocab at 0x1a732e623d0>,
#  'techniques': <gensim.models.keyedvectors.Vocab at 0x1a732e62430>,
#  'resultant': <gensim.models.keyedvectors.Vocab at 0x1a732e62490>,
#  'distinctive': <gensim.models.keyedvectors.Vocab at 0x1a732e624f0>,
#  'internationally': <gensim.models.keyedvectors.Vocab at 0x1a732e62550>,
#  'recognised': <gensim.models.keyedvectors.Vocab at 0x1a732e625b0>,
#  'ranks': <gensim.models.keyedvectors.Vocab at 0x1a732e62610>,
#  'among': <gensim.models.keyedvectors.Vocab at 0x1a732e62670>,
#  'teas': <gensim.models.keyedvectors.Vocab at 0x1a732e626d0>,
#  'connects': <gensim.models.keyedvectors.Vocab at 0x1a732e62730>,
#  'plains': <gensim.models.keyedvectors.Vocab at 0x1a732e62790>,
#  'steam': <gensim.models.keyedvectors.Vocab at 0x1a732e627f0>,
#  'locomotives': <gensim.models.keyedvectors.Vocab at 0x1a732e62850>,
#  'still': <gensim.models.keyedvectors.Vocab at 0x1a732e628b0>,
#  'service': <gensim.models.keyedvectors.Vocab at 0x1a732e62910>,
#  'several': <gensim.models.keyedvectors.Vocab at 0x1a732e62970>,
#  'style': <gensim.models.keyedvectors.Vocab at 0x1a732e629d0>,
#  'private': <gensim.models.keyedvectors.Vocab at 0x1a732e62a30>,
#  'schools': <gensim.models.keyedvectors.Vocab at 0x1a732e62a90>,
#  'attract': <gensim.models.keyedvectors.Vocab at 0x1a732e62af0>,
#  'pupils': <gensim.models.keyedvectors.Vocab at 0x1a732e62b50>,
#  'neighbouring': <gensim.models.keyedvectors.Vocab at 0x1a732e62bb0>,
#  'countries': <gensim.models.keyedvectors.Vocab at 0x1a732e62c10>,
#  'varied': <gensim.models.keyedvectors.Vocab at 0x1a732e62c70>,
#  'culture': <gensim.models.keyedvectors.Vocab at 0x1a732e62cd0>,
#  'reflects': <gensim.models.keyedvectors.Vocab at 0x1a732e62d30>,
#  'diverse': <gensim.models.keyedvectors.Vocab at 0x1a732e62d90>,
#  'demographic': <gensim.models.keyedvectors.Vocab at 0x1a732e62df0>,
#  'milieu': <gensim.models.keyedvectors.Vocab at 0x1a732e62e50>,
#  'comprising': <gensim.models.keyedvectors.Vocab at 0x1a732e62eb0>,
#  'lepcha': <gensim.models.keyedvectors.Vocab at 0x1a732e62f10>,
#  'khampa': <gensim.models.keyedvectors.Vocab at 0x1a732e62f70>,
#  'gorkha': <gensim.models.keyedvectors.Vocab at 0x1a732e62fd0>,
#  'kirati': <gensim.models.keyedvectors.Vocab at 0x1a732e60070>,
#  'newar': <gensim.models.keyedvectors.Vocab at 0x1a732e600d0>,
#  'sherpa': <gensim.models.keyedvectors.Vocab at 0x1a732e60130>,
#  'bhutia': <gensim.models.keyedvectors.Vocab at 0x1a732e60190>,
#  'bengali': <gensim.models.keyedvectors.Vocab at 0x1a732e601f0>,
#  'mainland': <gensim.models.keyedvectors.Vocab at 0x1a732e60250>,
#  'ethno': <gensim.models.keyedvectors.Vocab at 0x1a732e602b0>,
#  'linguistic': <gensim.models.keyedvectors.Vocab at 0x1a732e60310>,
#  'groups': <gensim.models.keyedvectors.Vocab at 0x1a732e60370>,
#  'alongside': <gensim.models.keyedvectors.Vocab at 0x1a732e603d0>,
#  'kalimpong': <gensim.models.keyedvectors.Vocab at 0x1a732e60430>,
#  'centre': <gensim.models.keyedvectors.Vocab at 0x1a732e60490>,
#  'social': <gensim.models.keyedvectors.Vocab at 0x1a732e604f0>,
#  'movement': <gensim.models.keyedvectors.Vocab at 0x1a732e60550>,
#  'summer': <gensim.models.keyedvectors.Vocab at 0x1a732e605b0>}

# %%
vector=model.wv['darjeeling']
print('Dimension=',len(vector))
vector
# Out:
# Dimension= 100
# array([ 1.9370120e-03,  3.4818607e-03, -3.1168960e-04,  2.7818087e-04,
#        -1.0071611e-03,  5.0145471e-03,  4.9465303e-03,  2.3420008e-03,
#         4.5267162e-03,  1.6683658e-03, -3.9893105e-03, -2.0132689e-03,
#        -2.4535933e-03,  3.9975424e-03,  4.8610521e-03,  2.8144144e-03,
#        -4.1822388e-04,  2.5118110e-03,  2.2952612e-03,  1.0731708e-03,
#         5.2927696e-04, -4.1402807e-03,  2.4674141e-03,  3.3959397e-03,
#         1.0605638e-03, -4.6038358e-03,  3.4082942e-03,  3.3720534e-03,
#        -6.3982728e-04, -2.0175469e-03,  2.5084539e-05,  4.2950562e-03,
#        -7.0209365e-04,  2.1440808e-03,  1.8218694e-03, -3.3221429e-03,
#        -5.2052108e-04,  4.7623063e-03, -2.5205936e-03, -4.8871799e-03,
#        -5.8632391e-04,  4.5023295e-03, -1.3559896e-03,  3.8356271e-03,
#        -3.6166434e-03,  2.6001781e-03,  3.5038341e-03, -4.0307385e-03,
#         1.2443042e-03, -2.2772392e-03,  5.4242660e-04,  4.0437547e-03,
#         3.1278075e-03, -1.5368095e-03, -2.1413916e-03,  1.8676956e-03,
#        -2.6518146e-03,  6.3060131e-04, -1.1633845e-03, -3.0801310e-03,
#        -4.9095391e-03, -5.4943998e-04, -3.3142853e-03, -2.4393422e-03,
#         4.5461315e-03, -1.0190081e-03, -2.4835742e-03,  3.7908177e-03,
#         1.3550643e-03, -3.9681653e-03, -4.0836674e-03,  1.1756492e-03,
#         2.9036277e-03, -4.3155025e-03, -3.4587360e-03, -4.3398491e-03,
#        -1.4667861e-03,  1.0952275e-03, -1.0469179e-03, -1.8308514e-03,
#         2.5820313e-03, -1.7243583e-03,  3.5763572e-03,  2.4252308e-03,
#         1.0954364e-03,  2.9356363e-03,  2.0339363e-03,  2.9937224e-03,
#        -4.7512762e-03, -3.9322432e-03,  4.0015434e-03, -8.2215283e-04,
#         1.5087195e-03, -4.1227289e-03, -3.2326684e-03, -1.4161895e-03,
#         2.0187031e-03,  2.2426378e-03,  1.7831250e-03, -3.7664582e-03],
#       dtype=float32)

# %%
similar=model.wv.most_similar('indian')
similar
# Out:
# [('culture', 0.29485154151916504),
#  ('early', 0.2314891368150711),
#  ('gorkhaland', 0.2191665917634964),
#  ('kangchenjunga', 0.20079994201660156),
#  ('ranks', 0.18273811042308807),
#  ('called', 0.16538554430007935),
#  ('pupils', 0.16463813185691833),
#  ('growers', 0.15901511907577515),
#  ('movement', 0.14898432791233063),
#  ('darjeeling', 0.14345210790634155)]
